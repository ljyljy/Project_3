# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split
import gc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print('Loading Properties...')
properties2016 = pd.read_csv('../Resources/properties_2016.csv', low_memory = False)
properties2017 = pd.read_csv('../Resources/properties_2017.csv', low_memory = False)

print('Loading Train...')
train2016 = pd.read_csv('../Resources/train_2016_v2.csv', parse_dates=['transactiondate'], low_memory=False)
train2017 = pd.read_csv('../Resources/train_2017.csv', parse_dates=['transactiondate'], low_memory=False)

print('Loading Sample ...')
sample_submission = pd.read_csv('../Resources/sample_submission.csv', low_memory=False)
# Out:
# Loading Properties...
# Loading Train...
# Loading Sample ...

# %%
def add_date_features(df):
    df["transaction_year"] = df["transactiondate"].dt.year
    df["transaction_month"] = df["transactiondate"].dt.month
    df["transaction_day"] = df["transactiondate"].dt.day
    df["transaction_quarter"] = df["transactiondate"].dt.quarter
    df.drop(["transactiondate"], inplace=True, axis=1)
    return df

# %%
train2016 = add_date_features(train2016)
train2017 = add_date_features(train2017)

sample_submission['parcelid'] = sample_submission['ParcelId']

print('Merge Train & Test with Properties...')
train2016 = pd.merge(train2016, properties2016, how='left', on='parcelid')
train2017 = pd.merge(train2017, properties2017, how='left', on='parcelid')
test_df = pd.merge(sample_submission, properties2016, how='left', on='parcelid')

print('Concat Train 2016 & 2017...')
train_df = pd.concat([train2016, train2017], axis=0)

del properties2016, properties2017, train2016, train2017
gc.collect();

print("Train: ", train_df.shape)
print("Test: ", test_df.shape)
# Out:
# Merge Train & Test with Properties...
# Concat Train 2016 & 2017...
# Train:  (167888, 63)
# Test:  (2985217, 65)

# %%
# 98% missing value will be dropoff
missing_perc_thresh = 0.98
exclude_missing = []
num_rows = train_df.shape[0]
for c in train_df.columns:
    num_missing = train_df[c].isnull().sum()
    if num_missing == 0:
        continue
    missing_frac = num_missing / float(num_rows)
    if missing_frac > missing_perc_thresh:
        exclude_missing.append(c)
print("We exclude: %s" % exclude_missing)
print(len(exclude_missing))
# Out:
# We exclude: ['architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedsquarefeet13', 'finishedsquarefeet6', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'storytypeid', 'typeconstructiontypeid', 'yardbuildingsqft26', 'fireplaceflag']
# 13

# %%
exclude_unique = []
for c in train_df.columns:
    num_uniques = len(train_df[c].unique())
    if train_df[c].isnull().sum() != 0:
        num_uniques -= 1
    if num_uniques == 1:
        exclude_unique.append(c)
print("We exclude: %s" % exclude_unique)
print(len(exclude_unique))
# Out:
# We exclude: ['decktypeid', 'hashottuborspa', 'poolcnt', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'storytypeid', 'fireplaceflag', 'taxdelinquencyflag']
# 9

# %%
exclude_other = ['parcelid', 'logerror','propertyzoningdesc']
train_features = []
for c in train_df.columns:
    if c not in exclude_missing \
       and c not in exclude_other and c not in exclude_unique:
        train_features.append(c)
print("We use these for training: %s" % train_features)
print(len(train_features))
# Out:
# We use these for training: ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'finishedsquarefeet15', 'finishedsquarefeet50', 'fips', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'propertycountylandusecode', 'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr', 'unitcnt', 'yardbuildingsqft17', 'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyyear', 'censustractandblock']
# 43

# %%
cat_feature_inds = []
cat_unique_thresh = 1000
for i, c in enumerate(train_features):
    num_uniques = len(train_df[c].unique())
    if num_uniques < cat_unique_thresh \
       and not 'sqft' in c \
       and not 'cnt' in c \
       and not 'nbr' in c \
       and not 'number' in c:
        cat_feature_inds.append(i)
        
print("Cat features are: %s" % [train_features[ind] for ind in cat_feature_inds])
# Out:
# Cat features are: ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'buildingqualitytypeid', 'fips', 'heatingorsystemtypeid', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 'yearbuilt', 'assessmentyear', 'taxdelinquencyyear']

# %%
print ("Replacing NaN values by -999 !!")
train_df.fillna(-999, inplace=True)
test_df.fillna(-999, inplace=True)
# Out:
# Replacing NaN values by -999 !!

# %%
def print_feature_importance(model, pool, X_train):
    feature_importances = model.get_feature_importance(pool)
    feature_names = X_train.columns
    for score, name in sorted(zip(feature_importances, feature_names), reverse=True):
        print('{}\t{}'.format(name, score))

# %%
for i in [train_features[ind] for ind in cat_feature_inds]:
    if train_df[i].dtype == 'float':
        train_df[i] = train_df[i].astype('int')

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df[train_features], train_df.logerror, test_size=0.2, random_state=99)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

all_pool = Pool(train_df[train_features], train_df.logerror, cat_feature_inds)
train_pool = Pool(X_train, y_train, cat_feature_inds)
test_pool = Pool(X_test, y_test, cat_feature_inds)
# Out:
# (134310, 43) (134310,)
# (33578, 43) (33578,)

# %%
catboost_parameters = {
    'iterations': 400,
    'learning_rate': 0.035,
    'depth': 7,
    'verbose': 20,
#     'l2_leaf_reg': 1000,
    'task_type': 'GPU',
    'loss_function': 'MAE',
    'eval_metric': 'MAE',
    'random_seed': 0,
}

# %%
model = CatBoostRegressor(**catboost_parameters)
model.fit(train_pool, eval_set=test_pool)
# Out:
# 0:	learn: 0.0683956	test: 0.0696829	best: 0.0696829 (0)	total: 25.3ms	remaining: 10.1s
# 20:	learn: 0.0677368	test: 0.0692307	best: 0.0692307 (20)	total: 549ms	remaining: 9.91s
# 40:	learn: 0.0675111	test: 0.0691698	best: 0.0691698 (40)	total: 1.02s	remaining: 8.94s
# 60:	learn: 0.0673069	test: 0.0691288	best: 0.0691288 (60)	total: 1.5s	remaining: 8.33s
# 80:	learn: 0.0671440	test: 0.0690974	best: 0.0690957 (77)	total: 1.99s	remaining: 7.83s
# 100:	learn: 0.0670153	test: 0.0690786	best: 0.0690775 (97)	total: 2.5s	remaining: 7.4s
# 120:	learn: 0.0669019	test: 0.0690779	best: 0.0690746 (114)	total: 2.99s	remaining: 6.89s
# 140:	learn: 0.0667897	test: 0.0690826	best: 0.0690746 (114)	total: 3.48s	remaining: 6.4s
# 160:	learn: 0.0666795	test: 0.0690751	best: 0.0690697 (158)	total: 3.96s	remaining: 5.88s
# 180:	learn: 0.0665374	test: 0.0690532	best: 0.0690530 (179)	total: 4.44s	remaining: 5.38s
# 200:	learn: 0.0664186	test: 0.0690501	best: 0.0690489 (194)	total: 4.96s	remaining: 4.91s
# 220:	learn: 0.0663076	test: 0.0690542	best: 0.0690489 (194)	total: 5.44s	remaining: 4.4s
# 240:	learn: 0.0662149	test: 0.0690488	best: 0.0690488 (240)	total: 5.92s	remaining: 3.9s
# 260:	learn: 0.0661206	test: 0.0690561	best: 0.0690461 (254)	total: 6.4s	remaining: 3.41s
# 280:	learn: 0.0659930	test: 0.0690792	best: 0.0690461 (254)	total: 6.87s	remaining: 2.91s
# 300:	learn: 0.0658901	test: 0.0690812	best: 0.0690461 (254)	total: 7.35s	remaining: 2.42s
# 320:	learn: 0.0657862	test: 0.0690987	best: 0.0690461 (254)	total: 7.83s	remaining: 1.93s
# 340:	learn: 0.0656975	test: 0.0690912	best: 0.0690461 (254)	total: 8.31s	remaining: 1.44s
# 360:	learn: 0.0655893	test: 0.0690968	best: 0.0690461 (254)	total: 8.8s	remaining: 951ms
# 380:	learn: 0.0655062	test: 0.0691041	best: 0.0690461 (254)	total: 9.29s	remaining: 463ms
# 399:	learn: 0.0654012	test: 0.0690999	best: 0.0690461 (254)	total: 9.76s	remaining: 0us
# bestTest = 0.06904605595
# bestIteration = 254
# Shrink model to first 255 iterations.

# %%
num_ensembles = 5
# ensemble models
models = [None] * num_ensembles
for i in range(num_ensembles):
    print("\nTraining (ensemble): %d ..." % (i))
    catboost_parameters['random_seed'] = i
    models[i] = CatBoostRegressor(**catboost_parameters)
    models[i].fit(train_pool, eval_set=test_pool)
    print('-- Feature Importance --')
    print_feature_importance(models[i], train_pool, X_train)
# Out:
# Training (ensemble): 0 ...
# 0:	learn: 0.0683956	test: 0.0696829	best: 0.0696829 (0)	total: 23.3ms	remaining: 9.31s
# 20:	learn: 0.0677368	test: 0.0692307	best: 0.0692307 (20)	total: 569ms	remaining: 10.3s
# 40:	learn: 0.0675111	test: 0.0691698	best: 0.0691698 (40)	total: 1.04s	remaining: 9.08s
# 60:	learn: 0.0673069	test: 0.0691288	best: 0.0691288 (60)	total: 1.55s	remaining: 8.61s
# 80:	learn: 0.0671440	test: 0.0690974	best: 0.0690957 (77)	total: 2.04s	remaining: 8.02s
# 100:	learn: 0.0670153	test: 0.0690786	best: 0.0690775 (97)	total: 2.55s	remaining: 7.56s
# 120:	learn: 0.0669019	test: 0.0690779	best: 0.0690746 (114)	total: 3.06s	remaining: 7.04s
# 140:	learn: 0.0667897	test: 0.0690826	best: 0.0690746 (114)	total: 3.56s	remaining: 6.55s
# 160:	learn: 0.0666795	test: 0.0690751	best: 0.0690697 (158)	total: 4.06s	remaining: 6.02s
# 180:	learn: 0.0665374	test: 0.0690532	best: 0.0690530 (179)	total: 4.56s	remaining: 5.52s
# 200:	learn: 0.0664186	test: 0.0690501	best: 0.0690489 (194)	total: 5.09s	remaining: 5.04s
# 220:	learn: 0.0663076	test: 0.0690542	best: 0.0690489 (194)	total: 5.58s	remaining: 4.52s
# 240:	learn: 0.0662149	test: 0.0690488	best: 0.0690488 (240)	total: 6.08s	remaining: 4.01s
# 260:	learn: 0.0661206	test: 0.0690561	best: 0.0690461 (254)	total: 6.59s	remaining: 3.51s
# 280:	learn: 0.0659930	test: 0.0690792	best: 0.0690461 (254)	total: 7.06s	remaining: 2.99s
# 300:	learn: 0.0658901	test: 0.0690812	best: 0.0690461 (254)	total: 7.57s	remaining: 2.49s
# 320:	learn: 0.0657862	test: 0.0690987	best: 0.0690461 (254)	total: 8.08s	remaining: 1.99s
# 340:	learn: 0.0656975	test: 0.0690911	best: 0.0690461 (254)	total: 8.59s	remaining: 1.49s
# 360:	learn: 0.0655893	test: 0.0690968	best: 0.0690461 (254)	total: 9.1s	remaining: 983ms
# 380:	learn: 0.0655062	test: 0.0691041	best: 0.0690461 (254)	total: 9.6s	remaining: 479ms
# 399:	learn: 0.0654012	test: 0.0690999	best: 0.0690461 (254)	total: 10.1s	remaining: 0us
# bestTest = 0.06904606322
# bestIteration = 254
# Shrink model to first 255 iterations.
# -- Feature Importance --
# regionidzip	7.390542344633232
# finishedsquarefeet12	7.0384916369953805
# taxamount	6.788500994448337
# transaction_month	6.652155831680876
# yearbuilt	6.641139857046078
# propertycountylandusecode	5.046272685289442
# regionidcity	4.850497252222425
# lotsizesquarefeet	4.24617341893441
# calculatedfinishedsquarefeet	3.7726660434867045
# regionidneighborhood	3.6967672812428827
# transaction_day	3.5331681417280794
# buildingqualitytypeid	3.079698101003836
# taxvaluedollarcnt	2.8497834002522384
# structuretaxvaluedollarcnt	2.8226794822521923
# longitude	2.753308317774911
# latitude	2.4402743691837054
# propertylandusetypeid	2.3952216887022657
# landtaxvaluedollarcnt	2.339989190631253
# transaction_quarter	2.2655645126328547
# taxdelinquencyyear	2.066596215748403
# heatingorsystemtypeid	1.9874650497040234
# transaction_year	1.588782035499218
# garagetotalsqft	1.4105924397113996
# rawcensustractandblock	1.3732823351881758
# censustractandblock	1.233253426244446
# regionidcounty	1.1970161051213306
# assessmentyear	1.1738457120197012
# fullbathcnt	1.1018203413595933
# bedroomcnt	1.001114155645667
# airconditioningtypeid	0.9157224657331928
# fips	0.7731218159592556
# unitcnt	0.5834981070835993
# calculatedbathnbr	0.5430278924844215
# garagecarcnt	0.4934465738548643
# bathroomcnt	0.36496555051324175
# fireplacecnt	0.3223079745406777
# yardbuildingsqft17	0.32126005931808355
# finishedfloor1squarefeet	0.29689229291394353
# numberofstories	0.23908654996664636
# finishedsquarefeet15	0.23811902537289995
# finishedsquarefeet50	0.07730096147832465
# roomcnt	0.06433024207813054
# threequarterbathnbr	0.03025812231957893
#
# Training (ensemble): 1 ...
# 0:	learn: 0.0684092	test: 0.0696832	best: 0.0696832 (0)	total: 26ms	remaining: 10.4s
# 20:	learn: 0.0677327	test: 0.0692164	best: 0.0692164 (20)	total: 545ms	remaining: 9.84s
# 40:	learn: 0.0674909	test: 0.0691510	best: 0.0691510 (40)	total: 1.05s	remaining: 9.22s
# 60:	learn: 0.0673208	test: 0.0691324	best: 0.0691315 (59)	total: 1.58s	remaining: 8.77s
# 80:	learn: 0.0671564	test: 0.0691041	best: 0.0691041 (80)	total: 2.08s	remaining: 8.19s
# 100:	learn: 0.0670062	test: 0.0690762	best: 0.0690762 (100)	total: 2.6s	remaining: 7.7s
# 120:	learn: 0.0668639	test: 0.0690771	best: 0.0690742 (112)	total: 3.08s	remaining: 7.11s
# 140:	learn: 0.0667169	test: 0.0690745	best: 0.0690742 (112)	total: 3.6s	remaining: 6.61s
# 160:	learn: 0.0665765	test: 0.0690628	best: 0.0690585 (158)	total: 4.12s	remaining: 6.11s
# 180:	learn: 0.0664413	test: 0.0690668	best: 0.0690581 (164)	total: 4.61s	remaining: 5.58s
# 200:	learn: 0.0663402	test: 0.0690446	best: 0.0690442 (199)	total: 5.11s	remaining: 5.06s
# 220:	learn: 0.0662438	test: 0.0690522	best: 0.0690406 (207)	total: 5.63s	remaining: 4.56s
# 240:	learn: 0.0661551	test: 0.0690603	best: 0.0690406 (207)	total: 6.13s	remaining: 4.04s
# 260:	learn: 0.0660672	test: 0.0690583	best: 0.0690406 (207)	total: 6.63s	remaining: 3.53s
# 280:	learn: 0.0659439	test: 0.0690485	best: 0.0690406 (207)	total: 7.1s	remaining: 3.01s
# 300:	learn: 0.0658606	test: 0.0690562	best: 0.0690406 (207)	total: 7.6s	remaining: 2.5s
# 320:	learn: 0.0657523	test: 0.0690585	best: 0.0690406 (207)	total: 8.1s	remaining: 1.99s
# 340:	learn: 0.0656707	test: 0.0690595	best: 0.0690406 (207)	total: 8.58s	remaining: 1.48s
# 360:	learn: 0.0655513	test: 0.0690603	best: 0.0690406 (207)	total: 9.06s	remaining: 979ms
# 380:	learn: 0.0654488	test: 0.0690629	best: 0.0690406 (207)	total: 9.57s	remaining: 477ms
# 399:	learn: 0.0653666	test: 0.0690589	best: 0.0690406 (207)	total: 10s	remaining: 0us
# bestTest = 0.06904063917
# bestIteration = 207
# Shrink model to first 208 iterations.
# -- Feature Importance --
# regionidzip	7.970319666023138
# finishedsquarefeet12	7.57972054492248
# transaction_month	6.823327016652159
# taxamount	6.447177556062502
# yearbuilt	5.6573195189874905
# propertycountylandusecode	5.2045897390646285
# calculatedfinishedsquarefeet	5.029989279684089
# taxvaluedollarcnt	4.325927055216402
# structuretaxvaluedollarcnt	4.01921870374298
# regionidcity	3.853895935244266
# propertylandusetypeid	3.6074064086157374
# regionidneighborhood	3.5610012455651203
# lotsizesquarefeet	3.170195828313493
# buildingqualitytypeid	3.0025522092256653
# transaction_day	2.9847099432795137
# transaction_quarter	2.3211940250691194
# taxdelinquencyyear	2.1429212973039338
# latitude	2.0706930111718966
# heatingorsystemtypeid	1.9062508357049854
# airconditioningtypeid	1.7972531067234574
# longitude	1.6915923461824764
# censustractandblock	1.5919297684196414
# bedroomcnt	1.5466422481564859
# landtaxvaluedollarcnt	1.3611050848114399
# assessmentyear	1.3467090245246822
# rawcensustractandblock	1.0879902931991554
# fips	0.9571359481939666
# regionidcounty	0.8879716635717396
# garagetotalsqft	0.881520927312865
# finishedsquarefeet15	0.8533572001930173
# transaction_year	0.7738430334813436
# bathroomcnt	0.737174724945992
# finishedsquarefeet50	0.5356511663688864
# fullbathcnt	0.5177510740640064
# unitcnt	0.3937269209839299
# garagecarcnt	0.3593188113946464
# calculatedbathnbr	0.33592643956901996
# yardbuildingsqft17	0.2679989438926411
# fireplacecnt	0.17692704413733015
# numberofstories	0.12658838467533307
# finishedfloor1squarefeet	0.07497240364793045
# roomcnt	0.018503621700427176
# threequarterbathnbr	0.0
#
# Training (ensemble): 2 ...
# 0:	learn: 0.0684186	test: 0.0697021	best: 0.0697021 (0)	total: 22.6ms	remaining: 9.01s
# 20:	learn: 0.0677337	test: 0.0691949	best: 0.0691944 (19)	total: 522ms	remaining: 9.42s
# 40:	learn: 0.0675157	test: 0.0691332	best: 0.0691270 (39)	total: 1.02s	remaining: 8.95s
# 60:	learn: 0.0673153	test: 0.0690878	best: 0.0690878 (60)	total: 1.52s	remaining: 8.47s
# 80:	learn: 0.0671919	test: 0.0690700	best: 0.0690700 (78)	total: 2.05s	remaining: 8.08s
# 100:	learn: 0.0670446	test: 0.0690584	best: 0.0690554 (91)	total: 2.54s	remaining: 7.51s
# 120:	learn: 0.0669042	test: 0.0690579	best: 0.0690518 (118)	total: 3.03s	remaining: 6.99s
# 140:	learn: 0.0667510	test: 0.0690267	best: 0.0690266 (139)	total: 3.54s	remaining: 6.5s
# 160:	learn: 0.0665973	test: 0.0690313	best: 0.0690210 (145)	total: 4.03s	remaining: 5.98s
# 180:	learn: 0.0664675	test: 0.0690254	best: 0.0690210 (145)	total: 4.53s	remaining: 5.48s
# 200:	learn: 0.0663772	test: 0.0690160	best: 0.0690140 (198)	total: 5.02s	remaining: 4.97s
# 220:	learn: 0.0662578	test: 0.0690263	best: 0.0690099 (202)	total: 5.51s	remaining: 4.47s
# 240:	learn: 0.0661499	test: 0.0690273	best: 0.0690099 (202)	total: 6.02s	remaining: 3.97s
# 260:	learn: 0.0660528	test: 0.0690281	best: 0.0690099 (202)	total: 6.53s	remaining: 3.48s
# 280:	learn: 0.0659589	test: 0.0690339	best: 0.0690099 (202)	total: 7.03s	remaining: 2.98s
# 300:	learn: 0.0658637	test: 0.0690352	best: 0.0690099 (202)	total: 7.53s	remaining: 2.48s
# 320:	learn: 0.0657706	test: 0.0690345	best: 0.0690099 (202)	total: 8.05s	remaining: 1.98s
# 340:	learn: 0.0656598	test: 0.0690461	best: 0.0690099 (202)	total: 8.55s	remaining: 1.48s
# 360:	learn: 0.0655360	test: 0.0690529	best: 0.0690099 (202)	total: 9.05s	remaining: 978ms
# 380:	learn: 0.0654389	test: 0.0690528	best: 0.0690099 (202)	total: 9.55s	remaining: 476ms
# 399:	learn: 0.0653341	test: 0.0690561	best: 0.0690099 (202)	total: 10s	remaining: 0us
# bestTest = 0.06900991255
# bestIteration = 202
# Shrink model to first 203 iterations.
# -- Feature Importance --
# regionidzip	8.250825217549652
# yearbuilt	7.054449617166805
# finishedsquarefeet12	6.977635906555425
# transaction_month	6.691409589557911
# propertycountylandusecode	5.975345208028586
# taxamount	5.6947812683528625
# calculatedfinishedsquarefeet	5.50842375001799
# regionidneighborhood	4.488456193635043
# lotsizesquarefeet	4.078123086098829
# transaction_day	3.543298448285397
# regionidcity	3.532279365885372
# structuretaxvaluedollarcnt	3.107824411424678
# taxvaluedollarcnt	3.0717632103072163
# landtaxvaluedollarcnt	2.7360427538704095
# propertylandusetypeid	2.6468790500622346
# censustractandblock	2.615257943244913
# buildingqualitytypeid	2.3261387607652977
# latitude	2.1142109288063535
# longitude	1.8877543154384224
# taxdelinquencyyear	1.83432757939544
# assessmentyear	1.831108386240139
# transaction_quarter	1.8106027998462548
# heatingorsystemtypeid	1.4896531018754955
# fips	1.40575665688963
# bedroomcnt	1.0942334920868841
# airconditioningtypeid	1.0611829309755156
# garagetotalsqft	0.8977698511629171
# rawcensustractandblock	0.8513370822900127
# unitcnt	0.8375231729670307
# regionidcounty	0.6822552153859733
# garagecarcnt	0.5499456685407496
# transaction_year	0.5475586046488599
# calculatedbathnbr	0.5268207681967838
# numberofstories	0.4603643207719494
# bathroomcnt	0.4452679458754702
# yardbuildingsqft17	0.3455424703108434
# fullbathcnt	0.313144948415712
# finishedsquarefeet15	0.20249955301328895
# fireplacecnt	0.17157297622695855
# threequarterbathnbr	0.16358954897317218
# finishedsquarefeet50	0.10311453515859127
# roomcnt	0.0739293656989028
# finishedfloor1squarefeet	0.0
#
# Training (ensemble): 3 ...
# 0:	learn: 0.0684349	test: 0.0697127	best: 0.0697127 (0)	total: 23.4ms	remaining: 9.34s
# 20:	learn: 0.0677697	test: 0.0692034	best: 0.0692030 (19)	total: 516ms	remaining: 9.31s
# 40:	learn: 0.0675123	test: 0.0691452	best: 0.0691438 (38)	total: 1.02s	remaining: 8.91s
# 60:	learn: 0.0673079	test: 0.0690868	best: 0.0690868 (60)	total: 1.51s	remaining: 8.39s
# 80:	learn: 0.0671636	test: 0.0690514	best: 0.0690514 (80)	total: 1.97s	remaining: 7.75s
# 100:	learn: 0.0670333	test: 0.0690583	best: 0.0690514 (80)	total: 2.43s	remaining: 7.18s
# 120:	learn: 0.0668926	test: 0.0690523	best: 0.0690488 (112)	total: 2.92s	remaining: 6.74s
# 140:	learn: 0.0667764	test: 0.0690392	best: 0.0690386 (134)	total: 3.42s	remaining: 6.29s
# 160:	learn: 0.0666613	test: 0.0690366	best: 0.0690311 (146)	total: 3.94s	remaining: 5.85s
# 180:	learn: 0.0665363	test: 0.0690267	best: 0.0690266 (179)	total: 4.45s	remaining: 5.38s
# 200:	learn: 0.0664412	test: 0.0690169	best: 0.0690126 (196)	total: 4.96s	remaining: 4.91s
# 220:	learn: 0.0663076	test: 0.0690186	best: 0.0690126 (196)	total: 5.47s	remaining: 4.43s
# 240:	learn: 0.0662047	test: 0.0690116	best: 0.0690102 (236)	total: 5.97s	remaining: 3.94s
# 260:	learn: 0.0661011	test: 0.0690105	best: 0.0690090 (256)	total: 6.47s	remaining: 3.45s
# 280:	learn: 0.0659938	test: 0.0690085	best: 0.0690028 (269)	total: 6.98s	remaining: 2.96s
# 300:	learn: 0.0658936	test: 0.0690098	best: 0.0690028 (269)	total: 7.47s	remaining: 2.46s
# 320:	learn: 0.0657784	test: 0.0690190	best: 0.0690028 (269)	total: 7.97s	remaining: 1.96s
# 340:	learn: 0.0656922	test: 0.0690293	best: 0.0690028 (269)	total: 8.48s	remaining: 1.47s
# 360:	learn: 0.0655861	test: 0.0690302	best: 0.0690028 (269)	total: 8.99s	remaining: 971ms
# 380:	learn: 0.0654631	test: 0.0690301	best: 0.0690028 (269)	total: 9.48s	remaining: 473ms
# 399:	learn: 0.0653622	test: 0.0690307	best: 0.0690028 (269)	total: 9.96s	remaining: 0us
# bestTest = 0.06900279439
# bestIteration = 269
# Shrink model to first 270 iterations.
# -- Feature Importance --
# regionidzip	7.1483845561157136
# yearbuilt	6.831103373210149
# transaction_month	6.505607243621445
# finishedsquarefeet12	6.219794126592535
# calculatedfinishedsquarefeet	5.553189203268662
# regionidcity	5.387059073536838
# taxamount	5.369165769831235
# propertycountylandusecode	5.273897721651949
# transaction_day	4.438255828781513
# regionidneighborhood	4.250516269288898
# lotsizesquarefeet	3.2270998360312335
# structuretaxvaluedollarcnt	3.2023473589867253
# buildingqualitytypeid	2.9980274027600315
# propertylandusetypeid	2.9948930929176587
# taxvaluedollarcnt	2.5898068296869536
# transaction_quarter	2.3758782829152705
# assessmentyear	2.3324980612103126
# latitude	1.9873921139599606
# longitude	1.9414166001870126
# taxdelinquencyyear	1.9110371645776902
# censustractandblock	1.7806108478207199
# heatingorsystemtypeid	1.6973277053474276
# landtaxvaluedollarcnt	1.6852898342017308
# airconditioningtypeid	1.3326006747974457
# calculatedbathnbr	1.1189696020833997
# fips	1.0855962267997745
# bedroomcnt	1.0362191398169527
# transaction_year	1.0234945933895234
# garagetotalsqft	0.9117375564596888
# rawcensustractandblock	0.8527390093679589
# regionidcounty	0.7120265935168184
# bathroomcnt	0.5886867133617267
# unitcnt	0.5732231115960629
# garagecarcnt	0.5502671232434857
# yardbuildingsqft17	0.47620982588724625
# finishedsquarefeet50	0.4560247504735196
# fullbathcnt	0.4488672919341027
# threequarterbathnbr	0.2977505068225313
# numberofstories	0.23615811753749522
# finishedsquarefeet15	0.17595431859261673
# fireplacecnt	0.16224783825967595
# roomcnt	0.13055510310852922
# finishedfloor1squarefeet	0.13007360644969343
#
# Training (ensemble): 4 ...
# 0:	learn: 0.0684383	test: 0.0697183	best: 0.0697183 (0)	total: 20.2ms	remaining: 8.07s
# 20:	learn: 0.0677331	test: 0.0692134	best: 0.0692134 (20)	total: 517ms	remaining: 9.34s
# 40:	learn: 0.0675386	test: 0.0691459	best: 0.0691459 (40)	total: 1.01s	remaining: 8.89s
# 60:	learn: 0.0673634	test: 0.0691026	best: 0.0691026 (60)	total: 1.52s	remaining: 8.43s
# 80:	learn: 0.0672101	test: 0.0690800	best: 0.0690800 (80)	total: 2.03s	remaining: 7.99s
# 100:	learn: 0.0670712	test: 0.0690744	best: 0.0690744 (100)	total: 2.53s	remaining: 7.48s
# 120:	learn: 0.0669556	test: 0.0690700	best: 0.0690650 (116)	total: 3.03s	remaining: 6.99s
# 140:	learn: 0.0668102	test: 0.0690396	best: 0.0690395 (139)	total: 3.54s	remaining: 6.5s
# 160:	learn: 0.0666906	test: 0.0690459	best: 0.0690376 (146)	total: 4.04s	remaining: 6s
# 180:	learn: 0.0665666	test: 0.0690461	best: 0.0690376 (146)	total: 4.54s	remaining: 5.5s
# 200:	learn: 0.0664445	test: 0.0690500	best: 0.0690376 (146)	total: 5.05s	remaining: 5s
# 220:	learn: 0.0663363	test: 0.0690538	best: 0.0690376 (146)	total: 5.55s	remaining: 4.5s
# 240:	learn: 0.0662161	test: 0.0690537	best: 0.0690376 (146)	total: 6.09s	remaining: 4.01s
# 260:	learn: 0.0661169	test: 0.0690473	best: 0.0690376 (146)	total: 6.59s	remaining: 3.51s
# 280:	learn: 0.0660071	test: 0.0690450	best: 0.0690376 (146)	total: 7.09s	remaining: 3s
# 300:	learn: 0.0659163	test: 0.0690570	best: 0.0690376 (146)	total: 7.59s	remaining: 2.5s
# 320:	learn: 0.0658299	test: 0.0690593	best: 0.0690376 (146)	total: 8.1s	remaining: 1.99s
# 340:	learn: 0.0657332	test: 0.0690519	best: 0.0690376 (146)	total: 8.6s	remaining: 1.49s
# 360:	learn: 0.0656233	test: 0.0690548	best: 0.0690376 (146)	total: 9.11s	remaining: 984ms
# 380:	learn: 0.0654922	test: 0.0690610	best: 0.0690376 (146)	total: 9.63s	remaining: 480ms
# 399:	learn: 0.0654075	test: 0.0690565	best: 0.0690376 (146)	total: 10.1s	remaining: 0us
# bestTest = 0.06903757087
# bestIteration = 146
# Shrink model to first 147 iterations.
# -- Feature Importance --
# regionidzip	8.396892993476198
# finishedsquarefeet12	7.808146834174687
# taxamount	7.059764994172154
# transaction_month	6.921114412370147
# calculatedfinishedsquarefeet	5.8608856617566705
# propertycountylandusecode	5.652403940671489
# yearbuilt	5.355477886980283
# regionidneighborhood	4.950556791080101
# propertylandusetypeid	3.591332075228783
# regionidcity	3.491870816617188
# landtaxvaluedollarcnt	3.321455801594609
# taxvaluedollarcnt	3.240697489794746
# lotsizesquarefeet	3.100910324088463
# transaction_day	2.682037159331232
# buildingqualitytypeid	2.5602142538123163
# latitude	2.1513382416935523
# taxdelinquencyyear	2.010587684977357
# bedroomcnt	1.9643439568709262
# rawcensustractandblock	1.7972322702429764
# airconditioningtypeid	1.7246472621954576
# structuretaxvaluedollarcnt	1.5444099580692592
# assessmentyear	1.4915957247057554
# transaction_year	1.3448071276089446
# heatingorsystemtypeid	1.2783307056975397
# longitude	1.2681695193261984
# fullbathcnt	1.060932733981902
# censustractandblock	1.0242158208076915
# garagetotalsqft	0.998276537709539
# transaction_quarter	0.9562895087628925
# bathroomcnt	0.8433319368209199
# unitcnt	0.7014268655703426
# regionidcounty	0.6813653269629782
# fireplacecnt	0.5431465249731142
# yardbuildingsqft17	0.38798938497217883
# numberofstories	0.38078887367639086
# calculatedbathnbr	0.3739344639066329
# fips	0.36411071558132607
# finishedsquarefeet50	0.2957656191393033
# roomcnt	0.26002844651001733
# finishedsquarefeet15	0.1996312337702321
# finishedfloor1squarefeet	0.15872710497287248
# garagecarcnt	0.11065985974863321
# threequarterbathnbr	0.09015515559599317

# %%
for i in [train_features[ind] for ind in cat_feature_inds]:
    if test_df[i].dtype == 'float':
        test_df[i] = test_df[i].astype('int')

# %%
submission = pd.DataFrame({
    'ParcelId': test_df['parcelid'],
})

test_dates = {
    '201610': pd.Timestamp('2016-09-30'),
    '201611': pd.Timestamp('2016-10-31'),
    '201612': pd.Timestamp('2016-11-30'),
    '201710': pd.Timestamp('2017-09-30'),
    '201711': pd.Timestamp('2017-10-31'),
    '201712': pd.Timestamp('2017-11-30')
}

for label, test_date in test_dates.items():
    print("Predicting for: %s ... " % (label))
    test_df['transactiondate'] = test_date
    test_df = add_date_features(test_df)
    y_pred = 0.0
    for i in range(num_ensembles):
        print("Ensemble:", i)
        y_pred += models[i].predict(test_df[train_features])
    y_pred /= num_ensembles
    submission[label] = y_pred

submission_major = 2
print("Creating submission: submission_%03d.csv ..." % (submission_major))
submission.to_csv(
    'submission_%03d.csv' % (submission_major),
    float_format='%.4f',
    index=False)
print("Finished.")
# Out:
# Predicting for: 201610 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201611 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201612 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201710 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201711 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201712 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Creating submission: submission_002.csv ...
# Finished.
