# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout, BatchNormalization
from keras.layers.advanced_activations import PReLU
from keras.layers.noise import GaussianDropout
from keras.optimizers import Adam
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Imputer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
import datetime
import gc

# %%
def reduce_mem_usage(df):
    start_mem_usg = df.memory_usage().sum() / 1024**2 
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in df.columns:
        if df[col].dtype != object:  # Exclude strings            
            # Print current column type
            print("******************************")
            print("Column: ",col)
            print("dtype before: ",df[col].dtype)            
            # make variables for Int, max and min
            IsInt = False
            mx = df[col].max()
            mn = df[col].min()
            print("min for this col: ",mn)
            print("max for this col: ",mx)
            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(df[col]).all(): 
                NAlist.append(col)
                df[col].fillna(mn-1,inplace=True)  
                   
            # test if column can be converted to an integer
            asint = df[col].fillna(0).astype(np.int64)
            result = (df[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True            
            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        df[col] = df[col].astype(np.uint8)
                    elif mx < 65535:
                        df[col] = df[col].astype(np.uint16)
                    elif mx < 4294967295:
                        df[col] = df[col].astype(np.uint32)
                    else:
                        df[col] = df[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)    
            # Make float datatypes 32 bit
            else:
                df[col] = df[col].astype(np.float32)
            
            # Print new column type
            print("dtype after: ",df[col].dtype)
            print("******************************")
    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = df.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    return df, NAlist

# %%
df_merge, NAlist = reduce_mem_usage(pd.read_csv('../output/outlier_remove.csv'))
target = df_merge.logerror
features = df_merge.drop(['logerror'], axis = 1)
# Out:
# Memory usage of properties dataframe is : 58.97638702392578  MB
# ******************************
# Column:  N_ValueRatio
# dtype before:  float64
# min for this col:  0.009128934
# max for this col:  10669.578000000001
# dtype after:  float32
# ******************************
# ******************************
# Column:  N_life
# dtype before:  float64
# min for this col:  2.0
# max for this col:  194.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  N_zip_count
# dtype before:  float64
# min for this col:  1.0
# max for this col:  22025.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  airconditioningtypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  7
# dtype after:  uint8
# ******************************
# ******************************
# Column:  basementsqft
# dtype before:  float64
# min for this col:  0.0
# max for this col:  3560.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  bedroomcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  16.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  13
# dtype after:  uint8
# ******************************
# ******************************
# Column:  calculatedbathnbr
# dtype before:  float64
# min for this col:  1.0
# max for this col:  20.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  calculatedfinishedsquarefeet
# dtype before:  float64
# min for this col:  2.0
# max for this col:  35640.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  finishedfloor1squarefeet
# dtype before:  float64
# min for this col:  44.0
# max for this col:  6912.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  finishedsquarefeet12
# dtype before:  float64
# min for this col:  2.0
# max for this col:  21929.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  finishedsquarefeet50
# dtype before:  float64
# min for this col:  44.0
# max for this col:  12467.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  fips
# dtype before:  int64
# min for this col:  0
# max for this col:  3
# dtype after:  uint8
# ******************************
# ******************************
# Column:  fireplacecnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  5.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  garagecarcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  14.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  garagetotalsqft
# dtype before:  float64
# min for this col:  0.0
# max for this col:  4251.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  hashottuborspa
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  14
# dtype after:  uint8
# ******************************
# ******************************
# Column:  landtaxvaluedollarcnt
# dtype before:  float64
# min for this col:  22.0
# max for this col:  24500000.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  latitude
# dtype before:  float64
# min for this col:  33.339294
# max for this col:  34.818768
# dtype after:  float32
# ******************************
# ******************************
# Column:  longitude
# dtype before:  float64
# min for this col:  -119.47542
# max for this col:  -117.55463400000001
# dtype after:  float32
# ******************************
# ******************************
# Column:  lotsizesquarefeet
# dtype before:  float64
# min for this col:  167.0
# max for this col:  6971010.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  lotsizesquarefeet_refill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  6971010.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  max_temp
# dtype before:  float64
# min for this col:  82.35
# max for this col:  111.94
# dtype after:  float32
# ******************************
# ******************************
# Column:  min_temp
# dtype before:  float64
# min for this col:  14.08
# max for this col:  45.51
# dtype after:  float32
# ******************************
# ******************************
# Column:  numberofstories
# dtype before:  float64
# min for this col:  1.0
# max for this col:  6.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  parcelid
# dtype before:  int64
# min for this col:  10711738
# max for this col:  167689317
# dtype after:  uint32
# ******************************
# ******************************
# Column:  poolcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  1.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid2
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_fill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  238.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  16
# dtype after:  uint8
# ******************************
# ******************************
# Column:  rawcensustractandblock
# dtype before:  int64
# min for this col:  0
# max for this col:  99523
# dtype after:  uint32
# ******************************
# ******************************
# Column:  regionidcity_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  187
# dtype after:  uint8
# ******************************
# ******************************
# Column:  regionidcounty
# dtype before:  int64
# min for this col:  0
# max for this col:  3
# dtype after:  uint8
# ******************************
# ******************************
# Column:  regionidneighborhood_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  530
# dtype after:  uint16
# ******************************
# ******************************
# Column:  regionidzip_fill
# dtype before:  int64
# min for this col:  1
# max for this col:  406
# dtype after:  uint16
# ******************************
# ******************************
# Column:  roomcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  18.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  structuretaxvaluedollarcnt
# dtype before:  float64
# min for this col:  44.0
# max for this col:  11421790.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  taxamount
# dtype before:  float64
# min for this col:  49.08
# max for this col:  311064.06
# dtype after:  float32
# ******************************
# ******************************
# Column:  taxdelinquencyflag
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  taxvaluedollarcnt
# dtype before:  float64
# min for this col:  22.0
# max for this col:  26500000.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  threequarterbathnbr
# dtype before:  float64
# min for this col:  0.0
# max for this col:  7.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  unitcnt_fill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  237.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  yardbuildingsqft17
# dtype before:  float64
# min for this col:  11.0
# max for this col:  3191.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# min for this col:  1
# max for this col:  12
# dtype after:  uint8
# ******************************
# ******************************
# Column:  year
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  logerror
# dtype before:  float64
# min for this col:  -0.3997407
# max for this col:  0.41885680000000003
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  15.999002456665039  MB
# This is  27.127810406857407 % of the initial size

# %%
imputer= Imputer()
imputer.fit(features)
x_train = imputer.transform(features)
sc = StandardScaler()
x_train = sc.fit_transform(x_train)

len_x=int(x_train.shape[1])
print("len_x is:",len_x)

# Neural Network
print("\nSetting up neural network model...")
nn = Sequential()
nn.add(Dense(units = 400 , kernel_initializer = 'normal', input_dim = len_x))
nn.add(PReLU())
nn.add(Dropout(.4))
nn.add(Dense(units = 160 , kernel_initializer = 'normal'))
nn.add(PReLU())
nn.add(BatchNormalization())
nn.add(Dropout(.6))
nn.add(Dense(units = 64 , kernel_initializer = 'normal'))
nn.add(PReLU())
nn.add(BatchNormalization())
nn.add(Dropout(.5))
nn.add(Dense(units = 26, kernel_initializer = 'normal'))
nn.add(PReLU())
nn.add(BatchNormalization())
nn.add(Dropout(.6))
nn.add(Dense(1, kernel_initializer='normal'))
nn.compile(loss='mae', optimizer=Adam(lr=4e-3, decay=1e-4))

y_train = target.values
print("\nFitting neural network model...")
nn.fit(np.array(x_train), np.array(y_train), batch_size = 32, epochs = 70, verbose=2)
# Out:
# /local/home/ningzesun/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# len_x is: 46
#
# Setting up neural network model...
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Fitting neural network model...
# Epoch 1/70
#  - 26s - loss: 0.0542
# Epoch 2/70
#  - 25s - loss: 0.0530
# Epoch 3/70
#  - 25s - loss: 0.0529
# Epoch 4/70
#  - 25s - loss: 0.0528
# Epoch 5/70
#  - 26s - loss: 0.0527
# Epoch 6/70
#  - 26s - loss: 0.0526
# Epoch 7/70
#  - 26s - loss: 0.0526
# Epoch 8/70
#  - 26s - loss: 0.0526
# Epoch 9/70
#  - 26s - loss: 0.0525
# Epoch 10/70
#  - 26s - loss: 0.0525
# Epoch 11/70
#  - 26s - loss: 0.0525
# Epoch 12/70
#  - 26s - loss: 0.0525
# Epoch 13/70
#  - 26s - loss: 0.0524
# Epoch 14/70
#  - 26s - loss: 0.0525
# Epoch 15/70
#  - 26s - loss: 0.0524
# Epoch 16/70
#  - 26s - loss: 0.0524
# Epoch 17/70
#  - 26s - loss: 0.0524
# Epoch 18/70
#  - 26s - loss: 0.0524
# Epoch 19/70
#  - 26s - loss: 0.0524
# Epoch 20/70
#  - 25s - loss: 0.0524
# Epoch 21/70
#  - 26s - loss: 0.0523
# Epoch 22/70
#  - 26s - loss: 0.0523
# Epoch 23/70
#  - 26s - loss: 0.0523
# Epoch 24/70
#  - 26s - loss: 0.0523
# Epoch 25/70
#  - 26s - loss: 0.0523
# Epoch 26/70
#  - 26s - loss: 0.0523
# Epoch 27/70
#  - 26s - loss: 0.0523
# Epoch 28/70
#  - 26s - loss: 0.0523
# Epoch 29/70
#  - 26s - loss: 0.0523
# Epoch 30/70
#  - 26s - loss: 0.0523
# Epoch 31/70
#  - 26s - loss: 0.0523
# Epoch 32/70
#  - 25s - loss: 0.0523
# Epoch 33/70
#  - 26s - loss: 0.0523
# Epoch 34/70
#  - 26s - loss: 0.0522
# Epoch 35/70
#  - 26s - loss: 0.0522
# Epoch 36/70
#  - 26s - loss: 0.0522
# Epoch 37/70
#  - 25s - loss: 0.0522
# Epoch 38/70
#  - 26s - loss: 0.0522
# Epoch 39/70
#  - 26s - loss: 0.0522
# Epoch 40/70
#  - 26s - loss: 0.0522
# Epoch 41/70
#  - 25s - loss: 0.0522
# Epoch 42/70
#  - 26s - loss: 0.0522
# Epoch 43/70
#  - 26s - loss: 0.0522
# Epoch 44/70
#  - 26s - loss: 0.0522
# Epoch 45/70
#  - 26s - loss: 0.0522
# Epoch 46/70
#  - 26s - loss: 0.0522
# Epoch 47/70
#  - 26s - loss: 0.0522
# Epoch 48/70
#  - 26s - loss: 0.0522
# Epoch 49/70
#  - 25s - loss: 0.0522
# Epoch 50/70
#  - 26s - loss: 0.0522
# Epoch 51/70
#  - 26s - loss: 0.0522
# Epoch 52/70
#  - 26s - loss: 0.0522
# Epoch 53/70
#  - 26s - loss: 0.0522
# Epoch 54/70
#  - 26s - loss: 0.0522
# Epoch 55/70
#  - 26s - loss: 0.0522
# Epoch 56/70
#  - 26s - loss: 0.0522
# Epoch 57/70
#  - 26s - loss: 0.0522
# Epoch 58/70
#  - 26s - loss: 0.0522
# Epoch 59/70
#  - 26s - loss: 0.0521
# Epoch 60/70
#  - 26s - loss: 0.0521
# Epoch 61/70
#  - 26s - loss: 0.0521
# Epoch 62/70
#  - 26s - loss: 0.0521
# Epoch 63/70
#  - 26s - loss: 0.0521
# Epoch 64/70
#  - 26s - loss: 0.0521
# Epoch 65/70
#  - 26s - loss: 0.0521
# Epoch 66/70
#  - 26s - loss: 0.0521
# Epoch 67/70
#  - 26s - loss: 0.0522
# Epoch 68/70
#  - 26s - loss: 0.0521
# Epoch 69/70
#  - 26s - loss: 0.0521
# Epoch 70/70
#  - 26s - loss: 0.0521
#
# Predicting with neural network model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-56220be0f440> in <module>
#      35 print("\nPredicting with neural network model...")
#      36 #print("x_test.shape:",x_test.shape)
# ---> 37 y_pred_ann = nn.predict(x_test)
#      38
#      39 print( "\nPreparing results for write..." )
#
# NameError: name 'x_test' is not defined

# %%
df_sub_2016, NA_list = reduce_mem_usage(pd.read_csv('../output/final_sub_2016.csv').drop_duplicates('parcelid'))
df_sub_2016['year'] = 0
results = {}
for month in [10,11]:
    print(month)
    df_sub_2016['month'] = month
    print(df_sub_2016.shape)
    imputer.fit(df_sub_2016)
    x_test = imputer.transform(df_sub_2016)
    sc = StandardScaler()
    x_train = sc.fit_transform(x_train)
    x_test = sc.transform(x_test)
    y_pred_ann = nn.predict(x_test)
    results[month] = y_pred_ann
    del x_test
    gc.collect()
for i in results.keys():
    df_sub_2016[str(i)] = results[i]
df_sub_2016[str(12)] = y_pred_ann
df_sub = pd.read_csv('../Resources/sample_submission.csv')
df_sub = df_sub.rename(columns = {'ParcelId': 'parcelid'})
df_sub = pd.merge(df_sub[['parcelid']], df_sub_2016[['parcelid', '10', '11', '12']].drop_duplicates('parcelid'),
                  how = 'left', on = 'parcelid')
df_sub = df_sub.rename(columns = {'10': '201610', '11': '201611', '12': '201612'}).drop_duplicates('parcelid')
del df_sub_2016
gc.collect()
df_sub_2017, NA_list = reduce_mem_usage(pd.read_csv('../output/final_sub_2017.csv').drop_duplicates('parcelid'))
df_sub_2017['year'] = 1
results = {}
for month in [10,11]:
    df_sub_2017['month'] = month
    imputer.fit(df_sub_2017)
    x_test = imputer.transform(df_sub_2017)
    sc = StandardScaler()
    x_train = sc.fit_transform(x_train)
    x_test = sc.transform(x_test)
    y_pred_ann = nn.predict(x_test)
    results[month] = y_pred_ann
for i in results.keys():
    df_sub_2017[str(i)] = results[i]
df_sub_2017[str(12)] = y_pred_ann
df_sub = pd.merge(df_sub[['parcelid', '201610', '201611', '201612']], 
                  df_sub_2017[['parcelid', '10', '11', '12']].drop_duplicates('parcelid'), 
                  how = 'left', on = 'parcelid')
df_sub = df_sub.rename(columns = {'10': '201710', '11': '201711', '12': '201712'})
del df_sub_2017
gc.collect()
df_sub.to_csv('../output/submission/nn_opt.csv', index = False)
# Out:
# Memory usage of properties dataframe is : 1070.443717956543  MB
# ******************************
# Column:  N_ValueRatio
# dtype before:  float64
# min for this col:  0.000298495780264653
# max for this col:  105355.63072025467
# dtype after:  float32
# ******************************
# ******************************
# Column:  N_life
# dtype before:  float64
# min for this col:  3.0
# max for this col:  217.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  N_zip_count
# dtype before:  float64
# min for this col:  1.0
# max for this col:  22021.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  airconditioningtypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  7
# dtype after:  uint8
# ******************************
# ******************************
# Column:  basementsqft
# dtype before:  float64
# min for this col:  0.0
# max for this col:  8516.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  bedroomcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  20.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  13
# dtype after:  uint8
# ******************************
# ******************************
# Column:  calculatedbathnbr
# dtype before:  float64
# min for this col:  1.0
# max for this col:  20.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  calculatedfinishedsquarefeet
# dtype before:  float64
# min for this col:  1.0
# max for this col:  952576.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  finishedfloor1squarefeet
# dtype before:  float64
# min for this col:  3.0
# max for this col:  31303.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  finishedsquarefeet12
# dtype before:  float64
# min for this col:  1.0
# max for this col:  290345.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  finishedsquarefeet50
# dtype before:  float64
# min for this col:  3.0
# max for this col:  31303.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  fips
# dtype before:  int64
# min for this col:  0
# max for this col:  3
# dtype after:  uint8
# ******************************
# ******************************
# Column:  fireplacecnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  9.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  garagecarcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  25.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  garagetotalsqft
# dtype before:  float64
# min for this col:  0.0
# max for this col:  7749.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  hashottuborspa
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  14
# dtype after:  uint8
# ******************************
# ******************************
# Column:  landtaxvaluedollarcnt
# dtype before:  float64
# min for this col:  1.0
# max for this col:  90246219.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  latitude
# dtype before:  float64
# min for this col:  33.324388
# max for this col:  34.81965
# dtype after:  float32
# ******************************
# ******************************
# Column:  longitude
# dtype before:  float64
# min for this col:  -119.47578
# max for this col:  -117.554316
# dtype after:  float32
# ******************************
# ******************************
# Column:  lotsizesquarefeet
# dtype before:  float64
# min for this col:  100.0
# max for this col:  328263808.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  lotsizesquarefeet_refill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  328263800.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  max_temp
# dtype before:  float64
# min for this col:  82.35
# max for this col:  103.01
# dtype after:  float32
# ******************************
# ******************************
# Column:  min_temp
# dtype before:  float64
# min for this col:  13.4
# max for this col:  45.51
# dtype after:  float32
# ******************************
# ******************************
# Column:  numberofstories
# dtype before:  float64
# min for this col:  1.0
# max for this col:  41.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  parcelid
# dtype before:  int64
# min for this col:  10711725
# max for this col:  169601949
# dtype after:  uint32
# ******************************
# ******************************
# Column:  poolcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  1.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid2
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_fill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  239.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  16
# dtype after:  uint8
# ******************************
# ******************************
# Column:  rawcensustractandblock
# dtype before:  int64
# min for this col:  0
# max for this col:  99523
# dtype after:  uint32
# ******************************
# ******************************
# Column:  regionidcity_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  187
# dtype after:  uint8
# ******************************
# ******************************
# Column:  regionidcounty
# dtype before:  int64
# min for this col:  0
# max for this col:  3
# dtype after:  uint8
# ******************************
# ******************************
# Column:  regionidneighborhood_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  530
# dtype after:  uint16
# ******************************
# ******************************
# Column:  regionidzip_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  406
# dtype after:  uint16
# ******************************
# ******************************
# Column:  roomcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  96.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  structuretaxvaluedollarcnt
# dtype before:  float64
# min for this col:  1.0
# max for this col:  251486000.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  taxamount
# dtype before:  float64
# min for this col:  1.34
# max for this col:  3458861.12
# dtype after:  float32
# ******************************
# ******************************
# Column:  taxdelinquencyflag
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  taxvaluedollarcnt
# dtype before:  float64
# min for this col:  1.0
# max for this col:  282786000.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  threequarterbathnbr
# dtype before:  float64
# min for this col:  0.0
# max for this col:  7.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  unitcnt_fill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  997.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yardbuildingsqft17
# dtype before:  float64
# min for this col:  10.0
# max for this col:  7983.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# min for this col:  10
# max for this col:  10
# dtype after:  uint8
# ******************************
# ******************************
# Column:  year
# dtype before:  int64
# min for this col:  0
# max for this col:  0
# dtype after:  uint8
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  316.0086507797241  MB
# This is  29.52127659574468 % of the initial size
# 10
# (2985217, 46)
# 11
# (2985217, 46)
# Memory usage of properties dataframe is : 1070.443717956543  MB
# ******************************
# Column:  N_ValueRatio
# dtype before:  float64
# min for this col:  0.0032190426859692173
# max for this col:  106962.28942830618
# dtype after:  float32
# ******************************
# ******************************
# Column:  N_life
# dtype before:  float64
# min for this col:  2.0
# max for this col:  217.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  N_zip_count
# dtype before:  float64
# min for this col:  1.0
# max for this col:  22025.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  airconditioningtypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  7
# dtype after:  uint8
# ******************************
# ******************************
# Column:  basementsqft
# dtype before:  float64
# min for this col:  0.0
# max for this col:  8516.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  bedroomcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  25.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  13
# dtype after:  uint8
# ******************************
# ******************************
# Column:  calculatedbathnbr
# dtype before:  float64
# min for this col:  1.0
# max for this col:  32.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  calculatedfinishedsquarefeet
# dtype before:  float64
# min for this col:  1.0
# max for this col:  952576.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  finishedfloor1squarefeet
# dtype before:  float64
# min for this col:  1.0
# max for this col:  31303.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  finishedsquarefeet12
# dtype before:  float64
# min for this col:  1.0
# max for this col:  427079.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  finishedsquarefeet50
# dtype before:  float64
# min for this col:  3.0
# max for this col:  41906.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  fips
# dtype before:  int64
# min for this col:  0
# max for this col:  3
# dtype after:  uint8
# ******************************
# ******************************
# Column:  fireplacecnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  9.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  garagecarcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  25.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  garagetotalsqft
# dtype before:  float64
# min for this col:  0.0
# max for this col:  7749.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  hashottuborspa
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  14
# dtype after:  uint8
# ******************************
# ******************************
# Column:  landtaxvaluedollarcnt
# dtype before:  float64
# min for this col:  1.0
# max for this col:  94011079.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  latitude
# dtype before:  float64
# min for this col:  33.324388
# max for this col:  34.81965
# dtype after:  float32
# ******************************
# ******************************
# Column:  longitude
# dtype before:  float64
# min for this col:  -119.47578
# max for this col:  -117.554316
# dtype after:  float32
# ******************************
# ******************************
# Column:  lotsizesquarefeet
# dtype before:  float64
# min for this col:  100.0
# max for this col:  371000512.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  lotsizesquarefeet_refill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  328263800.0
# dtype after:  float32
# ******************************
# ******************************
# Column:  max_temp
# dtype before:  float64
# min for this col:  84.72
# max for this col:  111.94
# dtype after:  float32
# ******************************
# ******************************
# Column:  min_temp
# dtype before:  float64
# min for this col:  14.56
# max for this col:  41.8
# dtype after:  float32
# ******************************
# ******************************
# Column:  numberofstories
# dtype before:  float64
# min for this col:  1.0
# max for this col:  41.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  parcelid
# dtype before:  int64
# min for this col:  10711725
# max for this col:  169601949
# dtype after:  uint32
# ******************************
# ******************************
# Column:  poolcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  1.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid2
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_fill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  233.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid
# dtype before:  int64
# min for this col:  0
# max for this col:  16
# dtype after:  uint8
# ******************************
# ******************************
# Column:  rawcensustractandblock
# dtype before:  int64
# min for this col:  0
# max for this col:  99523
# dtype after:  uint32
# ******************************
# ******************************
# Column:  regionidcity_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  187
# dtype after:  uint8
# ******************************
# ******************************
# Column:  regionidcounty
# dtype before:  int64
# min for this col:  0
# max for this col:  3
# dtype after:  uint8
# ******************************
# ******************************
# Column:  regionidneighborhood_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  530
# dtype after:  uint16
# ******************************
# ******************************
# Column:  regionidzip_fill
# dtype before:  int64
# min for this col:  0
# max for this col:  406
# dtype after:  uint16
# ******************************
# ******************************
# Column:  roomcnt
# dtype before:  float64
# min for this col:  0.0
# max for this col:  96.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  structuretaxvaluedollarcnt
# dtype before:  float64
# min for this col:  1.0
# max for this col:  255321161.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  taxamount
# dtype before:  float64
# min for this col:  0.24
# max for this col:  3823175.65
# dtype after:  float32
# ******************************
# ******************************
# Column:  taxdelinquencyflag
# dtype before:  int64
# min for this col:  0
# max for this col:  1
# dtype after:  uint8
# ******************************
# ******************************
# Column:  taxvaluedollarcnt
# dtype before:  float64
# min for this col:  1.0
# max for this col:  319622473.0
# dtype after:  uint32
# ******************************
# ******************************
# Column:  threequarterbathnbr
# dtype before:  float64
# min for this col:  0.0
# max for this col:  7.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  unitcnt_fill
# dtype before:  float64
# min for this col:  0.0
# max for this col:  997.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  yardbuildingsqft17
# dtype before:  float64
# min for this col:  10.0
# max for this col:  7983.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# min for this col:  10
# max for this col:  10
# dtype after:  uint8
# ******************************
# ******************************
# Column:  year
# dtype before:  int64
# min for this col:  0
# max for this col:  0
# dtype after:  uint8
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  316.0086507797241  MB
# This is  29.52127659574468 % of the initial size
